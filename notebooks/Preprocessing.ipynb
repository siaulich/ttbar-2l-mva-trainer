# %%
import sys

sys.path.insert(0, "..")
from core.RootPreprocessor import (
    RootPreprocessor,
    PreprocessorConfig,
    preprocess_root_file,
    preprocess_root_directory,
    DataSampleConfig,
)
import numpy as np

# %%
threshold_config = DataSampleConfig(
    output_dir="/data/dust/group/atlas/ttreco/",
    name="threshold_sample",
    input_dir="/data/dust/group/atlas/ttreco/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/",
    preprocessor_config=PreprocessorConfig(
        tree_name="reco",
        save_initial_parton_info=True,
        lepton_parton_match_format="old",
    ),
)

preprocess_root_directory(
    nominal_config,
)

# %%
boosted_config = DataSampleConfig(
    output_dir="/data/dust/group/atlas/ttreco/",
    name="boosted_sample",
    input_dir="/root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/",
    preprocessor_config=PreprocessorConfig(
        tree_name="reco",
        save_initial_parton_info=True,
        save_nu_flows=True,
        lepton_parton_match_format="old",
    ),
    max_events=2_000_000,
)

preprocess_root_directory(
    test_sample_config,
)

# %%
threshold_config = DataSampleConfig(
    output_dir="/data/dust/group/atlas/ttreco/",
    name="threshold_sample",
    input_dir="/data/dust/group/atlas/ttreco/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/",
    preprocessor_config=PreprocessorConfig(
        tree_name="reco",
        save_initial_parton_info=True,
        lepton_parton_match_format="old",
        data_cuts={"truth_ttbar_mass": (None, 450000)},
    ),
)

preprocess_root_directory(
    threshold_config,
)

# %%
toponium_config = DataSampleConfig(
    output_dir="/data/dust/group/atlas/ttreco/",
    name="toponium",
    input_dir="/data/dust/group/atlas/ttreco/user.kbehr.802380.Py8EG_Toponium_2L.DAOD_PHYS.e8562_s4231_r13145_r13146_p6697.250918-v1_output",
    preprocessor_config=PreprocessorConfig(
        tree_name="reco",
        save_initial_parton_info=True,
        lepton_parton_match_format="old",
        data_cuts={"truth_ttbar_mass": (450000, None)},
    ),
)

preprocess_root_directory(
    boosted_config,
)

# %%
toponium_config = DataSampleConfig(
    output_dir="/data/dust/group/atlas/ttreco/",
    name="nominal",
    input_dir="/data/dust/group/atlas/ttreco/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/",
    preprocessor_config=PreprocessorConfig(
        tree_name="reco",
        save_initial_parton_info=True,
        lepton_parton_match_format="old",
    ),
)

preprocess_root_directory(
    toponium_config,
)

# %%
# Example: Preprocess to NPZ format
toponium_config = DataSampleConfig(
    output_dir="/data/dust/group/atlas/ttreco/",
    name="test_sample",
    input_dir="/data/dust/group/atlas/ttreco/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/",
    preprocessor_config=PreprocessorConfig(
        tree_name="reco",
        save_initial_parton_info=True,
        save_nu_flows=True,
        lepton_parton_match_format="old",
    ),
    max_events=2_000_000,
)

preprocess_root_directory(
    toponium_config,
)
